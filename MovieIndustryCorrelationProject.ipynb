# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np 
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
#read the data in a dataframe
df= pd.read_csv(r'C:\Users\dell\Desktop\Autoformation\movies.csv')

# %%
#printing the first 5 observations of out data frame
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#let's check if there is any missing data
for col in df.columns:
    pctmissing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col,pctmissing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
df= df.dropna()

# %%
#let's verify
for col in df.columns:
    pctmissing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col,pctmissing))
# Out:
# name-0.0%
# rating-0.0%
# genre-0.0%
# year-0.0%
# released-0.0%
# score-0.0%
# votes-0.0%
# director-0.0%
# writer-0.0%
# star-0.0%
# country-0.0%
# budget-0.0%
# gross-0.0%
# company-0.0%
# runtime-0.0%

# %%
# look at data types for each column
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'].replace([np.inf, -np.inf, np.nan], 0, inplace=True)
df['budget'] = df['budget'].astype('int64')
df['votes'].replace([np.inf, -np.inf, np.nan], 0, inplace=True)
df['votes'] = df['votes'].astype('int64')
df['gross'].replace([np.inf, -np.inf, np.nan], 0, inplace=True)
df['gross'] = df['gross'].astype('int64')
df['runtime'].replace([np.inf, -np.inf, np.nan], 0, inplace=True)
df['runtime'] = df['runtime'].astype('int64')

# %%
#let's verify if changes were applied
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime
# 5445  1534       47  237000000  2847246203     1382      162
# 7445  1470       47  356000000  2797501328      983      181
# 3045  1073       47  200000000  2201647264     1382      194
# 6663   356       47  245000000  2069521700      945      138
# 7244  1470       47  321000000  2048359754      983      149

# %%
#correct the date of the release of the movie

# %%
#by exctracting the year from the total date 
df['yearcorrect'] = df ['released'].astype(str).str[4:]

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime
# 5445  1534       47  237000000  2847246203     1382      162
# 7445  1470       47  356000000  2797501328      983      181
# 3045  1073       47  200000000  2201647264     1382      194
# 6663   356       47  245000000  2069521700      945      138
# 7244  1470       47  321000000  2048359754      983      149

# %%
# Drop column 'yearcorrect'
df.drop(labels='yearcorrect', axis=1, inplace=True)

# Verify that column 'yearcorrect' has been dropped
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime
# 5445  1534       47  237000000  2847246203     1382      162
# 7445  1470       47  356000000  2797501328      983      181
# 3045  1073       47  200000000  2201647264     1382      194
# 6663   356       47  245000000  2069521700      945      138
# 7244  1470       47  321000000  2048359754      983      149

# %%
#great
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime
# 5445  1534       47  237000000  2847246203     1382      162
# 7445  1470       47  356000000  2797501328      983      181
# 3045  1073       47  200000000  2201647264     1382      194
# 6663   356       47  245000000  2069521700      945      138
# 7244  1470       47  321000000  2048359754      983      149

# %%
#.str.extract(pat = '([0-9]{4})'): This uses the str.extract method, which extracts a regular expression pattern from the
#released column. In this case, the pattern ([0-9]{4}) matches any sequence of four consecutive digits.
#.astype(int): This converts the resulting extracted values from strings to integers.

# %%
#let's sort the observations based on the value of the column gross
df = df.sort_values(by='gross', ascending=False)
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382      162         2009
# 7445  1470       47  356000000  2797501328      983      181         2019
# 3045  1073       47  200000000  2201647264     1382      194         1997
# 6663   356       47  245000000  2069521700      945      138         2015
# 7244  1470       47  321000000  2048359754      983      149         2018

# %%
pd.set_option('display.max_rows', None)

# %%
df = df.sort_values(by='gross', ascending=False)
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382      162         2009
# 7445  1470       47  356000000  2797501328      983      181         2019
# 3045  1073       47  200000000  2201647264     1382      194         1997
# 6663   356       47  245000000  2069521700      945      138         2015
# 7244  1470       47  321000000  2048359754      983      149         2018

# %%
#drop any duplicates
#first let's see if there is any duplicates
df['company'].sort_values(ascending =False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 520                                      Zoetrope Studios
# 352                                      Zoetrope Studios
# 146                                      Zoetrope Studios
# 724                                      Zoetrope Studios
# 332                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 5885                              Zentropa Entertainments
# 3698                              Zentropa Entertainments
# 4297                              Zentropa Entertainments
# ...

# %%
#now lets drop duplicates
df['company'].drop_duplicates().sort_values(ascending =False)
#we only see distinct companies
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 520                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
#budget high correlation
#Nothing is better than to start with a scatter plot
plt.scatter(x=df['budget'],y=df['gross'])
plt.show()

# %%
plt.scatter(x=df['budget'],y=df['gross'])
plt.xlabel('Gross earnings')
plt.ylabel('Budget')
plt.title('Budget vs Gross Earnings')
plt.show()

# %%
#lets do a reg plot to determin if there is a linear relation between two variables
sns.regplot(x='budget', y = 'gross',data = df,scatter_kws={"color":"black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson') #pearson ,  kendall , spearman
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
#High correlation between budget and gross
correlation_matrix= df.corr(method='pearson')

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
#we will be looking at company
#this column isnt numerical 
new_df= df
for col in new_df :
    if (new_df[col].dtype== 'object' ):
        new_df[col]= new_df[col].astype('category')
        new_df[col] = new_df[col].cat.codes

# %%
new_df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382      162         2009
# 7445  1470       47  356000000  2797501328      983      181         2019
# 3045  1073       47  200000000  2201647264     1382      194         1997
# 6663   356       47  245000000  2069521700      945      138         2015
# 7244  1470       47  321000000  2048359754      983      149         2018

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382      162         2009
# 7445  1470       47  356000000  2797501328      983      181         2019
# 3045  1073       47  200000000  2201647264     1382      194         1997
# 6663   356       47  245000000  2069521700      945      138         2015
# 7244  1470       47  321000000  2048359754      983      149         2018

# %%
new_correlation_matrix = new_df.corr()
sns.heatmap(new_correlation_matrix, annot=True)
plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
#let's visualise this in a better way
corr_pairs = new_correlation_matrix.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
# budget       rating        -0.203946
# rating       gross         -0.181906
# gross        rating        -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# company      rating        -0.092357
# rating       company       -0.092357
# country      yearcorrect   -0.073569
# yearcorrect  country       -0.073569
# year         genre         -0.073167
# genre        year          -0.073167
#              company       -0.071334
# company      genre         -0.071334
# genre        yearcorrect   -0.069147
# yearcorrect  genre         -0.069147
# year         country       -0.066748
# country      year          -0.066748
# genre        runtime       -0.059237
# runtime      genre         -0.059237
# score        country       -0.043051
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#logical to have a high correlation between Yearcorrect and year
#did't expect huge correlation betweem votes and gross
